# %% [markdown]
# <a href="https://colab.research.google.com/github/smilesrgouveia/Aula/blob/main/TarefaTrilha2_PL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

school = pd.read_csv('http://meusite.mackenzie.br/rogerio/data_load/gapminder_school_men_15_to_24_years.csv')
school.head()
# Out:
#        country  1970  1971  1972  1973  ...   2011   2012   2013   2014   2015
# 0  Afghanistan  1.82  1.87  1.92  1.97  ...   4.84   4.94   5.05   5.16   5.27
# 1      Albania  5.47  5.58  5.69  5.80  ...  10.60  10.70  10.90  11.00  11.20
# 2      Algeria  2.77  2.86  2.95  3.04  ...   8.85   8.99   9.14   9.28   9.42
# 3      Andorra  9.16  9.30  9.44  9.58  ...  14.50  14.60  14.70  14.80  14.90
# 4       Angola  2.25  2.31  2.36  2.42  ...   5.66   5.78   5.90   6.02   6.14
#
# [5 rows x 47 columns]

# %%
school_BR = school[ school.country == 'Brazil' ]
school_BR
# Out:
#    country  1970  1971  1972  1973  1974  ...  2010  2011  2012  2013  2014  2015
# 23  Brazil   3.4  3.47  3.55  3.64  3.72  ...  7.55  7.68  7.81  7.94  8.08  8.21
#
# [1 rows x 47 columns]

# %%
school_AR = school[ school.country == 'Argentina' ]
school_AR
# Out:
#      country  1970  1971  1972  1973  1974  ...  2010  2011  2012  2013  2014  2015
# 6  Argentina  6.61  6.73  6.84  6.96  7.07  ...  11.1  11.2  11.4  11.5  11.6  11.7
#
# [1 rows x 47 columns]

# %%
BR = pd.melt(school_BR, id_vars=['country'])
BR.head()
# Out:
#   country variable  value
# 0  Brazil     1970   3.40
# 1  Brazil     1971   3.47
# 2  Brazil     1972   3.55
# 3  Brazil     1973   3.64
# 4  Brazil     1974   3.72

# %%
BR = BR.rename(columns={'variable':'year','value':'school'})
BR.head()
# Out:
#   country  year  school
# 0  Brazil  1970    3.40
# 1  Brazil  1971    3.47
# 2  Brazil  1972    3.55
# 3  Brazil  1973    3.64
# 4  Brazil  1974    3.72

# %%
AR = pd.melt(school_AR, id_vars=['country'])
AR.head()
# Out:
#      country variable  value
# 0  Argentina     1970   6.61
# 1  Argentina     1971   6.73
# 2  Argentina     1972   6.84
# 3  Argentina     1973   6.96
# 4  Argentina     1974   7.07

# %%
AR = AR.rename(columns={'variable':'year','value':'school'})
AR.head()
# Out:
#      country  year  school
# 0  Argentina  1970    6.61
# 1  Argentina  1971    6.73
# 2  Argentina  1972    6.84
# 3  Argentina  1973    6.96
# 4  Argentina  1974    7.07

# %%
DF = pd.merge(BR,AR,on=['year'])
DF.head()
# Out:
#   country_x  year  school_x  country_y  school_y
# 0    Brazil  1970      3.40  Argentina      6.61
# 1    Brazil  1971      3.47  Argentina      6.73
# 2    Brazil  1972      3.55  Argentina      6.84
# 3    Brazil  1973      3.64  Argentina      6.96
# 4    Brazil  1974      3.72  Argentina      7.07

# %%
DF = DF.rename(columns={'school_x':'Brasil','school_y':'AR'})
DF.head()
# Out:
#   country_x  year  Brasil  country_y    AR
# 0    Brazil  1970    3.40  Argentina  6.61
# 1    Brazil  1971    3.47  Argentina  6.73
# 2    Brazil  1972    3.55  Argentina  6.84
# 3    Brazil  1973    3.64  Argentina  6.96
# 4    Brazil  1974    3.72  Argentina  7.07

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

plt.figure(figsize=(12,6))

sns.lineplot(x=DF.year, y=DF.Brasil, label='BRASIL')
sns.lineplot(x=DF.year, y=DF.AR, label='ARGENTINA')

plt.title('Escolaridade: BRASIL X ARGENTINA', fontsize=14)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Na análise de escolaridade, a Argentina é mais desenvolvida que o Brasil

# %%
import pandas as pd

tax = pd.read_csv('industry_percent_of_gdp.csv')
tax.head()
# Out:
#                 country  1959  1960  1961  1962  ...  2015  2016  2017  2018  2019
# 0                 Aruba   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1           Afghanistan   NaN   NaN   NaN   NaN  ...  10.5  10.1  13.4  14.1  12.5
# 2                Angola   NaN   NaN   NaN   NaN  ...  42.6  42.2  47.9  50.0  44.8
# 3               Albania   NaN   NaN   NaN   NaN  ...  21.1  20.4  21.3  20.2  19.7
# 4  United Arab Emirates   NaN   NaN   NaN   NaN  ...  41.4  42.6  47.0  46.2   NaN
#
# [5 rows x 62 columns]

# %%
tax_BR = tax[ tax.country == 'Brazil' ]
tax_BR


tax_AR = tax[ tax.country == 'Argentina' ]
tax_AR


BR = pd.melt(tax_BR, id_vars=['country'])
BR = BR.rename(columns={'variable':'year','value':'TAX'})
BR.head()

AR = pd.melt(tax_AR, id_vars=['country'])
AR = AR.rename(columns={'variable':'year','value':'TAX'})
AR.head()
# Out:
#      country  year  TAX
# 0  Argentina  1959  NaN
# 1  Argentina  1960  NaN
# 2  Argentina  1961  NaN
# 3  Argentina  1962  NaN
# 4  Argentina  1963  NaN

# %%
DF = pd.merge(BR,AR,on=['year'])
DF.head()

DF = DF.rename(columns={'TAX_x':'Brasil','TAX_y':'AR'})
DF.head()
# Out:
#   country_x  year  Brasil  country_y  AR
# 0    Brazil  1959    31.8  Argentina NaN
# 1    Brazil  1960    36.6  Argentina NaN
# 2    Brazil  1961    29.8  Argentina NaN
# 3    Brazil  1962    34.8  Argentina NaN
# 4    Brazil  1963    32.0  Argentina NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

plt.figure(figsize=(12,6))

sns.lineplot(x=DF.year, y=DF.Brasil, label='BRASIL')
sns.lineplot(x=DF.year, y=DF.AR, label='ARGENTINA')

plt.title('INDUSTRIA: BRASIL X ARGENTINA', fontsize=14)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Conclusão: A indutria de Brasil e Argentina vem caindo significativamente ao longo da história, em alguns periodos o Brasil chegou a ficar a frente, porém nos ultimos anos os dois países tem forte desaceleração.

# %% [markdown]
# # Nova seção
